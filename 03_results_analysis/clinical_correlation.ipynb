# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from statsmodels.api import add_constant

sns.set()

# %% [markdown]
# # read data

# %%
df_results = pd.read_csv('results.csv', index_col=0)
df_clinical = pd.read_csv('clinical_results.csv', index_col=0)

# %%
df_results.head()
# Out:
#      fold      patient      dice    TP       TN   FP    FN  n_pred  n_ref  \
# 0  fold_0  1525150.nii  0.000000     0  8623817    0   183       0    183
# 1  fold_0  1837909.nii  0.009756     4  9877584    0   812       4    816
# 2  fold_0  1856568.nii  0.580206  2984  5374842  717  3601    3701   6585
# 3  fold_0   324035.nii  0.000000     0  4504974  231   395     231    395
# 4  fold_0   390232.nii  0.299465   616  5378646  772  2110    1388   2726
#
#    precision    recall    type   view  dilated_dice
# 0   0.000000  0.000000  normal  axial      0.000000
# 1   1.000000  0.004902  normal  axial      0.023171
# 2   0.806269  0.453151  normal  axial      0.715341
# 3   0.000000  0.000000  normal  axial      0.000000
# 4   0.443804  0.225972  normal  axial      0.402042

# %% [markdown]
# # Preprocess data

# %%
df_clinical['Rutgeerts'] = df_clinical['Rutgeerts'].astype('str')

def convert(x):
    if x == 'nan':
        return float('nan')
    else:
        return float(x[-1])
        
df_clinical['Rutgeerts'] = df_clinical['Rutgeerts'].apply(lambda x: convert(x))

# %%
df_clinical = df_clinical.drop(['StudyDate', 'Data Colon', 'PCR data', 'Calc data'], axis=1)
df_clinical = df_clinical[['PatientID', 'delta_colon', 'Rutgeerts',
                           'SES CD', 'PCR', 'Calc', 'delta_pcr', 'delta_calc'
                        ]]

# %%
df_results['patient'] = df_results['patient'].apply(lambda x: int(x.split('.')[0]))
df_results
# Out:
#        fold  patient      dice    TP        TN    FP     FN  n_pred  n_ref  \
# 0    fold_0  1525150  0.000000     0   8623817     0    183       0    183
# 1    fold_0  1837909  0.009756     4   9877584     0    812       4    816
# 2    fold_0  1856568  0.580206  2984   5374842   717   3601    3701   6585
# 3    fold_0   324035  0.000000     0   4504974   231    395     231    395
# 4    fold_0   390232  0.299465   616   5378646   772   2110    1388   2726
# ..      ...      ...       ...   ...       ...   ...    ...     ...    ...
# 351  fold_4  5283984  0.379966  1927  56991720  2409   3880    4336   5807
# 352  fold_4   928807  0.221811   360   7200954  1206   1320    1566   1680
# 353  fold_4  9288071  0.000000     0  56991489     0   8447       0   8447
# 354  fold_4    94628  0.249403  2296  56983820   394  13426    2690  15722
# 355  fold_4     9571  0.000000     0   5166230     5    869       5    869
#
#      precision    recall    type      view  dilated_dice
# 0     0.000000  0.000000  normal     axial      0.000000
# 1     1.000000  0.004902  normal     axial      0.023171
# 2     0.806269  0.453151  normal     axial      0.715341
# 3     0.000000  0.000000  normal     axial      0.000000
# 4     0.443804  0.225972  normal     axial      0.402042
# ..         ...       ...     ...       ...           ...
# 351   0.444419  0.331841      da  sagittal      0.500049
# 352   0.229885  0.214286      da  sagittal      0.416513
# 353   0.000000  0.000000      da  sagittal      0.000000
# 354   0.853532  0.146037      da  sagittal      0.382142
# 355   0.000000  0.000000      da  sagittal      0.000000
#
# [356 rows x 14 columns]

# %%
df_join = df_clinical.merge(df_results, left_on='PatientID', right_on='patient')
df_join
# Out:
#      PatientID  delta_colon  Rutgeerts  SES CD  PCR  Calc  delta_pcr  \
# 0         9571         -3.0        NaN     NaN  NaN   NaN        NaN
# 1         9571         -3.0        NaN     NaN  NaN   NaN        NaN
# 2         9571         -3.0        NaN     NaN  NaN   NaN        NaN
# 3         9571         -3.0        NaN     NaN  NaN   NaN        NaN
# 4         9571         -3.0        NaN     NaN  NaN   NaN        NaN
# ..         ...          ...        ...     ...  ...   ...        ...
# 345    1412113          2.0        4.0     NaN  NaN   NaN        NaN
# 346    1412113          2.0        4.0     NaN  NaN   NaN        NaN
# 347    1412113          2.0        4.0     NaN  NaN   NaN        NaN
# 348    1412113          2.0        4.0     NaN  NaN   NaN        NaN
# 349    1412113          2.0        4.0     NaN  NaN   NaN        NaN
#
#      delta_calc    fold  patient  ...       TN    FP    FN  n_pred  n_ref  \
# 0           NaN  fold_4     9571  ...  5605318   408   674     408    674
# 1           NaN  fold_4     9571  ...  5912564   255   574     462    781
# 2           NaN  fold_4     9571  ...  5166235     0   869       0    869
# 3           NaN  fold_4     9571  ...  5605430   296   674     296    674
# 4           NaN  fold_4     9571  ...  5912377   442   484     739    781
# ..          ...     ...      ...  ...      ...   ...   ...     ...    ...
# 345         NaN  fold_4  1412113  ...  7562704   262   714     614   1066
# 346         NaN  fold_4  1412113  ...  8559803   181  1230     247   1296
# 347         NaN  fold_4  1412113  ...  5137397    17  1648     155   1786
# 348         NaN  fold_4  1412113  ...  7561009  1957   817    2206   1066
# 349         NaN  fold_4  1412113  ...  8559430   554  1226     624   1296
#
#      precision    recall    type      view dilated_dice
# 0     0.000000  0.000000  normal     axial     0.000000
# 1     0.448052  0.265045  normal   coronal     0.768302
# 2     0.000000  0.000000  normal  sagittal     0.000000
# 3     0.000000  0.000000      da     axial     0.000000
# 4     0.401894  0.380282      da   coronal     0.765789
# ..         ...       ...     ...       ...          ...
# 345   0.573290  0.330206  normal   coronal     0.685119
# 346   0.267206  0.050926  normal  sagittal     0.238496
# 347   0.890323  0.077268      da     axial     0.259660
# 348   0.112874  0.233583      da   coronal     0.294315
# 349   0.112179  0.054012      da  sagittal     0.221354
#
# [350 rows x 22 columns]

# %%
for metric in ['dice','dilated_dice']:
    for train_type in ['normal', 'da']:
        for view in ['axial', 'coronal', 'sagittal']:
                for clinical_metric in ['Rutgeerts', 'SES CD']:

                    temp = df_join[(df_join.view == view) & (df_join.type == train_type)][['patient', metric, 'n_ref', 'PCR', 'Calc', clinical_metric]]
                    temp = temp.dropna()

                    y = temp[[metric]]
                    x = temp[['n_ref', clinical_metric, 'PCR', 'Calc']]


                    scaler = MinMaxScaler()
                    scaler.fit(x)
                    x = pd.DataFrame(scaler.transform(x), columns=x.columns)

                    y = y.reset_index(drop=True)

                    model = sm.OLS(y, x).fit()

                    print(f'metric: {metric}')
                    print(f'view: {view}')
                    print(f'train type: {train_type}')
                    print(f'clinical metric: {clinical_metric}')

                    print()
                    print(model.summary())
                    print()
# Out:
# metric: dice
# view: axial
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.812
# Model:                            OLS   Adj. R-squared (uncentered):              0.737
# Method:                 Least Squares   F-statistic:                              10.83
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                     0.00117
# Time:                        16:06:55   Log-Likelihood:                          2.5054
# No. Observations:                  14   AIC:                                      2.989
# Df Residuals:                      10   BIC:                                      5.545
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2168      0.224      0.968      0.356      -0.282       0.716
# Rutgeerts      0.4146      0.111      3.734      0.004       0.167       0.662
# PCR            0.3628      0.237      1.529      0.157      -0.166       0.892
# Calc          -0.4156      0.279     -1.489      0.167      -1.037       0.206
# ==============================================================================
# Omnibus:                        0.592   Durbin-Watson:                   2.453
# Prob(Omnibus):                  0.744   Jarque-Bera (JB):                0.605
# Skew:                           0.218   Prob(JB):                        0.739
# Kurtosis:                       2.080   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: axial
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.417
# Model:                            OLS   Adj. R-squared (uncentered):              0.250
# Method:                 Least Squares   F-statistic:                              2.501
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0899
# Time:                        16:06:55   Log-Likelihood:                         -6.6752
# No. Observations:                  18   AIC:                                      21.35
# Df Residuals:                      14   BIC:                                      24.91
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.6017      0.520      1.158      0.266      -0.513       1.717
# SES CD         0.3472      0.335      1.038      0.317      -0.370       1.065
# PCR           -0.4129      0.382     -1.082      0.298      -1.232       0.406
# Calc           0.2274      0.411      0.554      0.589      -0.654       1.108
# ==============================================================================
# Omnibus:                        0.022   Durbin-Watson:                   1.172
# Prob(Omnibus):                  0.989   Jarque-Bera (JB):                0.106
# Skew:                           0.014   Prob(JB):                        0.948
# Kurtosis:                       2.625   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: coronal
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.539
# Model:                            OLS   Adj. R-squared (uncentered):              0.355
# Method:                 Least Squares   F-statistic:                              2.928
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0766
# Time:                        16:06:55   Log-Likelihood:                        -0.99979
# No. Observations:                  14   AIC:                                      10.00
# Df Residuals:                      10   BIC:                                      12.56
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.0654      0.232      0.282      0.784      -0.452       0.583
# Rutgeerts      0.2743      0.166      1.652      0.130      -0.096       0.644
# PCR            0.3653      0.297      1.229      0.247      -0.297       1.028
# Calc          -0.5328      0.364     -1.465      0.174      -1.343       0.277
# ==============================================================================
# Omnibus:                        2.211   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.331   Jarque-Bera (JB):                1.002
# Skew:                           0.154   Prob(JB):                        0.606
# Kurtosis:                       1.726   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: coronal
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.540
# Model:                            OLS   Adj. R-squared (uncentered):              0.417
# Method:                 Least Squares   F-statistic:                              4.393
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0150
# Time:                        16:06:55   Log-Likelihood:                         -1.1202
# No. Observations:                  19   AIC:                                      10.24
# Df Residuals:                      15   BIC:                                      14.02
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2455      0.250      0.984      0.341      -0.286       0.777
# SES CD         0.3698      0.235      1.577      0.136      -0.130       0.870
# PCR           -0.1225      0.257     -0.477      0.640      -0.670       0.425
# Calc           0.2316      0.300      0.771      0.453      -0.408       0.872
# ==============================================================================
# Omnibus:                        0.462   Durbin-Watson:                   1.516
# Prob(Omnibus):                  0.794   Jarque-Bera (JB):                0.446
# Skew:                           0.310   Prob(JB):                        0.800
# Kurtosis:                       2.577   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: sagittal
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.578
# Model:                            OLS   Adj. R-squared (uncentered):              0.409
# Method:                 Least Squares   F-statistic:                              3.422
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0521
# Time:                        16:06:55   Log-Likelihood:                         -2.8716
# No. Observations:                  14   AIC:                                      13.74
# Df Residuals:                      10   BIC:                                      16.30
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3662      0.292      1.255      0.238      -0.284       1.016
# Rutgeerts      0.1978      0.171      1.155      0.275      -0.184       0.579
# PCR            0.4395      0.339      1.296      0.224      -0.316       1.195
# Calc          -0.2595      0.401     -0.647      0.532      -1.152       0.634
# ==============================================================================
# Omnibus:                        0.857   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.652   Jarque-Bera (JB):                0.671
# Skew:                           0.126   Prob(JB):                        0.715
# Kurtosis:                       1.957   Cond. No.                         4.52
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: sagittal
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.482
# Model:                            OLS   Adj. R-squared (uncentered):              0.343
# Method:                 Least Squares   F-statistic:                              3.485
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0334
# Time:                        16:06:55   Log-Likelihood:                         -4.7135
# No. Observations:                  19   AIC:                                      17.43
# Df Residuals:                      15   BIC:                                      21.20
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3863      0.384      1.007      0.330      -0.431       1.204
# SES CD         0.4952      0.284      1.741      0.102      -0.111       1.101
# PCR           -0.3339      0.320     -1.045      0.313      -1.015       0.347
# Calc           0.2157      0.356      0.607      0.553      -0.542       0.973
# ==============================================================================
# Omnibus:                        2.010   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.366   Jarque-Bera (JB):                1.430
# Skew:                           0.657   Prob(JB):                        0.489
# Kurtosis:                       2.716   Cond. No.                         3.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: axial
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.753
# Model:                            OLS   Adj. R-squared (uncentered):              0.654
# Method:                 Least Squares   F-statistic:                              7.604
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                     0.00442
# Time:                        16:06:55   Log-Likelihood:                          1.2584
# No. Observations:                  14   AIC:                                      5.483
# Df Residuals:                      10   BIC:                                      8.040
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.5320      0.245      2.173      0.055      -0.013       1.077
# Rutgeerts      0.2504      0.121      2.063      0.066      -0.020       0.521
# PCR            0.3337      0.259      1.287      0.227      -0.244       0.912
# Calc          -0.2569      0.305     -0.842      0.419      -0.937       0.423
# ==============================================================================
# Omnibus:                        6.038   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                3.114
# Skew:                           1.100   Prob(JB):                        0.211
# Kurtosis:                       3.703   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: axial
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.399
# Model:                            OLS   Adj. R-squared (uncentered):              0.227
# Method:                 Least Squares   F-statistic:                              2.322
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                       0.108
# Time:                        16:06:55   Log-Likelihood:                         -6.5435
# No. Observations:                  18   AIC:                                      21.09
# Df Residuals:                      14   BIC:                                      24.65
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2808      0.516      0.544      0.595      -0.826       1.388
# SES CD         0.4488      0.332      1.351      0.198      -0.264       1.161
# PCR           -0.1325      0.379     -0.350      0.732      -0.945       0.680
# Calc           0.1229      0.408      0.301      0.768      -0.752       0.997
# ==============================================================================
# Omnibus:                        0.118   Durbin-Watson:                   1.312
# Prob(Omnibus):                  0.943   Jarque-Bera (JB):                0.266
# Skew:                          -0.157   Prob(JB):                        0.875
# Kurtosis:                       2.494   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: coronal
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.556
# Model:                            OLS   Adj. R-squared (uncentered):              0.378
# Method:                 Least Squares   F-statistic:                              3.128
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0654
# Time:                        16:06:55   Log-Likelihood:                        -0.64500
# No. Observations:                  14   AIC:                                      9.290
# Df Residuals:                      10   BIC:                                      11.85
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.0461      0.226      0.204      0.843      -0.458       0.550
# Rutgeerts      0.2454      0.162      1.516      0.160      -0.115       0.606
# PCR            0.4725      0.290      1.630      0.134      -0.173       1.118
# Calc          -0.5591      0.354     -1.577      0.146      -1.349       0.231
# ==============================================================================
# Omnibus:                        1.927   Durbin-Watson:                   1.585
# Prob(Omnibus):                  0.382   Jarque-Bera (JB):                0.975
# Skew:                           0.206   Prob(JB):                        0.614
# Kurtosis:                       1.775   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: coronal
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.546
# Model:                            OLS   Adj. R-squared (uncentered):              0.424
# Method:                 Least Squares   F-statistic:                              4.501
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0137
# Time:                        16:06:55   Log-Likelihood:                         -2.7573
# No. Observations:                  19   AIC:                                      13.51
# Df Residuals:                      15   BIC:                                      17.29
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2344      0.272      0.862      0.402      -0.345       0.814
# SES CD         0.4274      0.256      1.672      0.115      -0.118       0.972
# PCR           -0.2035      0.280     -0.727      0.478      -0.800       0.393
# Calc           0.3201      0.327      0.978      0.344      -0.378       1.018
# ==============================================================================
# Omnibus:                        0.517   Durbin-Watson:                   1.565
# Prob(Omnibus):                  0.772   Jarque-Bera (JB):                0.597
# Skew:                           0.302   Prob(JB):                        0.742
# Kurtosis:                       2.376   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: sagittal
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.676
# Model:                            OLS   Adj. R-squared (uncentered):              0.546
# Method:                 Least Squares   F-statistic:                              5.208
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0157
# Time:                        16:06:55   Log-Likelihood:                        -0.71443
# No. Observations:                  14   AIC:                                      9.429
# Df Residuals:                      10   BIC:                                      11.99
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.4074      0.250      1.629      0.134      -0.150       0.965
# Rutgeerts      0.1898      0.147      1.293      0.225      -0.137       0.517
# PCR            0.4774      0.291      1.642      0.132      -0.170       1.125
# Calc          -0.2450      0.344     -0.713      0.492      -1.010       0.520
# ==============================================================================
# Omnibus:                        0.866   Durbin-Watson:                   1.589
# Prob(Omnibus):                  0.649   Jarque-Bera (JB):                0.679
# Skew:                          -0.143   Prob(JB):                        0.712
# Kurtosis:                       1.960   Cond. No.                         4.52
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dice
# view: sagittal
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   dice   R-squared (uncentered):                   0.522
# Model:                            OLS   Adj. R-squared (uncentered):              0.394
# Method:                 Least Squares   F-statistic:                              4.094
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0194
# Time:                        16:06:55   Log-Likelihood:                         -5.0124
# No. Observations:                  19   AIC:                                      18.02
# Df Residuals:                      15   BIC:                                      21.80
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3266      0.390      0.838      0.415      -0.504       1.157
# SES CD         0.5627      0.289      1.948      0.070      -0.053       1.179
# PCR           -0.2884      0.325     -0.888      0.388      -0.980       0.403
# Calc           0.2391      0.361      0.662      0.518      -0.531       1.009
# ==============================================================================
# Omnibus:                        2.116   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.347   Jarque-Bera (JB):                1.507
# Skew:                           0.675   Prob(JB):                        0.471
# Kurtosis:                       2.718   Cond. No.                         3.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: axial
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.854
# Model:                            OLS   Adj. R-squared (uncentered):              0.796
# Method:                 Least Squares   F-statistic:                              14.68
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                    0.000344
# Time:                        16:06:55   Log-Likelihood:                         0.58041
# No. Observations:                  14   AIC:                                      6.839
# Df Residuals:                      10   BIC:                                      9.395
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3211      0.257      1.250      0.240      -0.251       0.894
# Rutgeerts      0.5549      0.127      4.356      0.001       0.271       0.839
# PCR            0.4335      0.272      1.592      0.142      -0.173       1.040
# Calc          -0.5002      0.320     -1.562      0.149      -1.214       0.213
# ==============================================================================
# Omnibus:                        1.577   Durbin-Watson:                   2.495
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                0.840
# Skew:                           0.046   Prob(JB):                        0.657
# Kurtosis:                       1.804   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: axial
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.434
# Model:                            OLS   Adj. R-squared (uncentered):              0.273
# Method:                 Least Squares   F-statistic:                              2.687
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0749
# Time:                        16:06:55   Log-Likelihood:                         -10.390
# No. Observations:                  18   AIC:                                      28.78
# Df Residuals:                      14   BIC:                                      32.34
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.7357      0.639      1.151      0.269      -0.635       2.106
# SES CD         0.3839      0.411      0.933      0.366      -0.498       1.266
# PCR           -0.4664      0.469     -0.994      0.337      -1.473       0.540
# Calc           0.3673      0.505      0.727      0.479      -0.716       1.450
# ==============================================================================
# Omnibus:                        0.097   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.953   Jarque-Bera (JB):                0.065
# Skew:                          -0.052   Prob(JB):                        0.968
# Kurtosis:                       2.726   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: coronal
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.558
# Model:                            OLS   Adj. R-squared (uncentered):              0.381
# Method:                 Least Squares   F-statistic:                              3.154
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0640
# Time:                        16:06:55   Log-Likelihood:                         -4.7673
# No. Observations:                  14   AIC:                                      17.53
# Df Residuals:                      10   BIC:                                      20.09
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.1264      0.304      0.416      0.686      -0.551       0.803
# Rutgeerts      0.3567      0.217      1.641      0.132      -0.128       0.841
# PCR            0.4740      0.389      1.218      0.251      -0.393       1.341
# Calc          -0.6570      0.476     -1.381      0.197      -1.717       0.403
# ==============================================================================
# Omnibus:                        2.188   Durbin-Watson:                   1.558
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                1.004
# Skew:                           0.167   Prob(JB):                        0.605
# Kurtosis:                       1.731   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: coronal
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.552
# Model:                            OLS   Adj. R-squared (uncentered):              0.432
# Method:                 Least Squares   F-statistic:                              4.617
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0125
# Time:                        16:06:55   Log-Likelihood:                         -7.3496
# No. Observations:                  19   AIC:                                      22.70
# Df Residuals:                      15   BIC:                                      26.48
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2197      0.346      0.634      0.536      -0.519       0.958
# SES CD         0.5617      0.326      1.725      0.105      -0.132       1.256
# PCR           -0.0566      0.356     -0.159      0.876      -0.816       0.703
# Calc           0.3160      0.417      0.758      0.460      -0.573       1.204
# ==============================================================================
# Omnibus:                        0.005   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.997   Jarque-Bera (JB):                0.189
# Skew:                          -0.025   Prob(JB):                        0.910
# Kurtosis:                       2.513   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: sagittal
# train type: normal
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.611
# Model:                            OLS   Adj. R-squared (uncentered):              0.456
# Method:                 Least Squares   F-statistic:                              3.931
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0360
# Time:                        16:06:55   Log-Likelihood:                         -5.9611
# No. Observations:                  14   AIC:                                      19.92
# Df Residuals:                      10   BIC:                                      22.48
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.4811      0.364      1.323      0.215      -0.329       1.292
# Rutgeerts      0.2704      0.213      1.267      0.234      -0.205       0.746
# PCR            0.5613      0.423      1.327      0.214      -0.381       1.504
# Calc          -0.3039      0.500     -0.608      0.557      -1.417       0.810
# ==============================================================================
# Omnibus:                        0.468   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.791   Jarque-Bera (JB):                0.524
# Skew:                           0.075   Prob(JB):                        0.769
# Kurtosis:                       2.064   Cond. No.                         4.52
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: sagittal
# train type: normal
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.531
# Model:                            OLS   Adj. R-squared (uncentered):              0.405
# Method:                 Least Squares   F-statistic:                              4.240
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0171
# Time:                        16:06:55   Log-Likelihood:                         -9.3478
# No. Observations:                  19   AIC:                                      26.70
# Df Residuals:                      15   BIC:                                      30.47
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3698      0.490      0.755      0.462      -0.674       1.413
# SES CD         0.7816      0.363      2.153      0.048       0.008       1.555
# PCR           -0.4552      0.408     -1.116      0.282      -1.324       0.414
# Calc           0.3080      0.454      0.679      0.508      -0.659       1.275
# ==============================================================================
# Omnibus:                        2.069   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.355   Jarque-Bera (JB):                1.490
# Skew:                           0.669   Prob(JB):                        0.475
# Kurtosis:                       2.700   Cond. No.                         3.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: axial
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.821
# Model:                            OLS   Adj. R-squared (uncentered):              0.749
# Method:                 Least Squares   F-statistic:                              11.45
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                    0.000943
# Time:                        16:06:55   Log-Likelihood:                        0.086078
# No. Observations:                  14   AIC:                                      7.828
# Df Residuals:                      10   BIC:                                      10.38
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.6472      0.266      2.431      0.035       0.054       1.240
# Rutgeerts      0.3625      0.132      2.746      0.021       0.068       0.657
# PCR            0.4214      0.282      1.494      0.166      -0.207       1.050
# Calc          -0.3172      0.332     -0.956      0.362      -1.056       0.422
# ==============================================================================
# Omnibus:                        3.062   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                1.649
# Skew:                           0.841   Prob(JB):                        0.438
# Kurtosis:                       2.999   Cond. No.                         4.78
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: axial
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.421
# Model:                            OLS   Adj. R-squared (uncentered):              0.256
# Method:                 Least Squares   F-statistic:                              2.547
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0859
# Time:                        16:06:55   Log-Likelihood:                         -10.429
# No. Observations:                  18   AIC:                                      28.86
# Df Residuals:                      14   BIC:                                      32.42
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.3732      0.640      0.583      0.569      -1.000       1.747
# SES CD         0.5262      0.412      1.277      0.222      -0.358       1.410
# PCR           -0.1268      0.470     -0.270      0.791      -1.135       0.882
# Calc           0.2023      0.506      0.400      0.695      -0.883       1.288
# ==============================================================================
# Omnibus:                        0.646   Durbin-Watson:                   1.316
# Prob(Omnibus):                  0.724   Jarque-Bera (JB):                0.539
# Skew:                          -0.373   Prob(JB):                        0.764
# Kurtosis:                       2.596   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: coronal
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.575
# Model:                            OLS   Adj. R-squared (uncentered):              0.405
# Method:                 Least Squares   F-statistic:                              3.382
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0537
# Time:                        16:06:55   Log-Likelihood:                         -4.2384
# No. Observations:                  14   AIC:                                      16.48
# Df Residuals:                      10   BIC:                                      19.03
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.0876      0.293      0.300      0.771      -0.564       0.739
# Rutgeerts      0.3127      0.209      1.494      0.166      -0.154       0.779
# PCR            0.6242      0.375      1.666      0.127      -0.211       1.459
# Calc          -0.6631      0.458     -1.447      0.178      -1.684       0.358
# ==============================================================================
# Omnibus:                        2.288   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.319   Jarque-Bera (JB):                1.043
# Skew:                           0.201   Prob(JB):                        0.594
# Kurtosis:                       1.725   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: coronal
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.553
# Model:                            OLS   Adj. R-squared (uncentered):              0.433
# Method:                 Least Squares   F-statistic:                              4.634
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0123
# Time:                        16:06:55   Log-Likelihood:                         -8.6590
# No. Observations:                  19   AIC:                                      25.32
# Df Residuals:                      15   BIC:                                      29.10
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2553      0.371      0.688      0.502      -0.536       1.046
# SES CD         0.6338      0.349      1.817      0.089      -0.110       1.377
# PCR           -0.2878      0.382     -0.754      0.463      -1.101       0.526
# Calc           0.4579      0.447      1.025      0.321      -0.494       1.410
# ==============================================================================
# Omnibus:                        0.517   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.772   Jarque-Bera (JB):                0.478
# Skew:                           0.328   Prob(JB):                        0.787
# Kurtosis:                       2.583   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: sagittal
# train type: da
# clinical metric: Rutgeerts
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.705
# Model:                            OLS   Adj. R-squared (uncentered):              0.586
# Method:                 Least Squares   F-statistic:                              5.961
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                      0.0102
# Time:                        16:06:55   Log-Likelihood:                         -3.8813
# No. Observations:                  14   AIC:                                      15.76
# Df Residuals:                      10   BIC:                                      18.32
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.5537      0.314      1.766      0.108      -0.145       1.252
# Rutgeerts      0.2557      0.184      1.390      0.195      -0.154       0.666
# PCR            0.6246      0.364      1.714      0.117      -0.188       1.437
# Calc          -0.3147      0.431     -0.731      0.482      -1.274       0.645
# ==============================================================================
# Omnibus:                        0.710   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.701   Jarque-Bera (JB):                0.694
# Skew:                          -0.328   Prob(JB):                        0.707
# Kurtosis:                       2.129   Cond. No.                         4.52
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# metric: dilated_dice
# view: sagittal
# train type: da
# clinical metric: SES CD
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           dilated_dice   R-squared (uncentered):                   0.568
# Model:                            OLS   Adj. R-squared (uncentered):              0.453
# Method:                 Least Squares   F-statistic:                              4.940
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):                     0.00964
# Time:                        16:06:55   Log-Likelihood:                         -9.6001
# No. Observations:                  19   AIC:                                      27.20
# Df Residuals:                      15   BIC:                                      30.98
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# n_ref          0.2652      0.496      0.534      0.601      -0.792       1.323
# SES CD         0.8611      0.368      2.341      0.033       0.077       1.645
# PCR           -0.3830      0.413     -0.927      0.369      -1.264       0.498
# Calc           0.3588      0.460      0.780      0.447      -0.621       1.339
# ==============================================================================
# Omnibus:                        1.929   Durbin-Watson:                   2.237
# Prob(Omnibus):                  0.381   Jarque-Bera (JB):                1.423
# Skew:                           0.648   Prob(JB):                        0.491
# Kurtosis:                       2.659   Cond. No.                         3.59
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia/anaconda3/envs/tesi2/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
